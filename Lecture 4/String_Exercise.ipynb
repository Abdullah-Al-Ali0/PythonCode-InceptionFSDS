# %% [markdown]
# 1. Find the length Of a given string without using the len() function
# 2. Extract username from a given email.
#
# - Ex:
#     if the email is bappy@gmail.com then the username should be bappy

# %%
s = input("Enter a string: ")

counter = 0
for i in s:
    counter += 1

print(counter)
# Out:
# 18

# %%
em = "abdullah@gamil.com"
em.index('@')
# Out:
# 8

# %%
email = input("Enter your email: ")

pos = email.index('@') # Find position of '@' character

print("Username:", email[0:pos]) # Username: abdullah
# Out:
# Username: abdullah

# %%
email = input("Enter your email: ")
username = email.split('@')[0]
print("Username:", username)
# Out:
# Username: abdullah

# %% [markdown]
# 3. Write a program that can check whether a given string is palindrome or not.
# - abba
# - mam
# - madam

# %%
word = input("Enter a word to check palindrome: ")

flag = True

for i in range(0, len(word)//2):
    if word[i] != word[len(word)-i-1]:
        flag = False
        print(f"{word} is not a palindrome")
        break

if flag:
    print(f"{word} is a palindrome")
# Out:
# asd is not a palindrome
